# %%
import numpy as np 
import numpy.random as npr
import pandas as pd

# %%
def Frechet_inv(u,g):
    return (np.log(u**(-1)))**(-g)

Frechet_inv(2,3)
# Out:
# -3.002780707156906

# %%
U = npr.rand(1000)

U = np.sort(U)

U
# Out:
# array([1.03935288e-04, 1.43070424e-03, 2.15869804e-03, 2.57751602e-03,
#        3.71405802e-03, 5.13989250e-03, 5.27517636e-03, 7.16774887e-03,
#        7.75526537e-03, 9.90239520e-03, 9.96028222e-03, 1.27513829e-02,
#        1.32830881e-02, 1.39153444e-02, 1.64834816e-02, 1.66483295e-02,
#        1.87923444e-02, 2.27481061e-02, 2.28048596e-02, 2.38158346e-02,
#        2.59623531e-02, 2.69560653e-02, 2.71535769e-02, 2.78334692e-02,
#        2.85159603e-02, 3.15107855e-02, 3.19739720e-02, 3.28254120e-02,
#        3.43979032e-02, 3.54332154e-02, 3.79575068e-02, 3.82391874e-02,
#        3.87141604e-02, 4.10811035e-02, 4.11064699e-02, 4.19559133e-02,
#        4.48465228e-02, 4.48485678e-02, 4.55362301e-02, 4.73122960e-02,
#        4.80099252e-02, 4.81351240e-02, 4.86746037e-02, 4.91398419e-02,
#        5.08101356e-02, 5.10176147e-02, 5.23040624e-02, 5.24569972e-02,
#        5.48611525e-02, 5.67758963e-02, 5.93671150e-02, 6.03905645e-02,
# ...
