# %% [markdown]
# # Import des modules pour le lecture des données et la création des features

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

import soundfile as sf


from scipy import signal

import librosa as lr
import librosa.feature as feat
import librosa.display


import os

# %%
path_test = '/home/ibotcazou/Bureau/Master_data_science/DATAS_M2/Apprentissage_Statistique_Panloup/Data_challenge/X__test'
path = '/home/ibotcazou/Bureau/Master_data_science/DATAS_M2/Apprentissage_Statistique_Panloup/Data_challenge/X_train'
path_Y = '/home/ibotcazou/Bureau/Master_data_science/DATAS_M2/Apprentissage_Statistique_Panloup/Data_challenge/Y_train_ofTdMHi.csv'

len(path)
# Out:
# 108

# %% [markdown]
# Le Format .WAV  qui signifie Waveform Audio File Format, est un format de fichier audio standard pour le stockage de l'audio en format brut, sans compression. Cela signifie qu'il offre une qualité sonore élevée, mais prend plus d'espace de stockage comparé à d'autres formats comme MP3.

# %% [markdown]
# # Découverte des données

# %%
fm = 3e3;fM=120e3;n_fft=2048


def visual_audio(path,display=True,fm = 1e3,fM=1e5,n_fft=1000):
    """
    Cette Fonction récupère la médiane de la valeur absolue de l'amplitude de certaines fréquences sur une Transformée de Fourier discrete roulante
    """

    # Ouvrir le fichier WAV en mode lecture
    if path.endswith(".wav"):
        # Obtenir des informations de base le vecteur audio et la fréquence d'échantillonnage
        audio, sr = sf.read(path) #audio est un array et sr est la freq d'echantillonnage
        n_frames = audio.shape[0] # donne le nb d'echantillon
        duration = n_frames/sr# en sec
        
        #n_fft=1000 # cela permet d'avoir plus de features si on l'augmente, ici on en a 501
        # Pour calculer la STFT qui est TF discrète sur une fenêtre glissante 
        tf_sig = lr.stft(audio, n_fft=n_fft)
        tf_sig = np.abs(tf_sig)

        #### features proposée par le challenge ####
        sos = signal.butter(6, [5000, 100000], 'bandpass', fs=sr, output='sos') # création  d'un filtre passe-bande les fréquences entre 1kHz et 100kHz
        sig = signal.sosfiltfilt(sos, audio) # Applique ce filtre à l'audio de manière bidirectionnelle pour réduire le décalage de phase.
        #Caractéristiques du signal
        rms = feat.rms(y=sig) #Calcule la RMS su signal qui est une mesure de l'amplitude du signal audio.
        sc = feat.spectral_centroid(y=sig, sr=sr) #centroïde spectral, une mesure qui indique où se situe le "centre de masse" du spectre.
        sb = feat.spectral_bandwidth(y=sig,sr=sr) #Calcule la largeur de bande spectrale, qui mesure la largeur du spectre.
        sfs = feat.spectral_flatness(y=sig) #Calcule la platitude spectrale, qui est une mesure de la « planéité » du spectre.

        features = [np.mean(rms), np.std(rms), np.min(rms), np.max(rms),\
                    np.mean(sc), np.std(sc), np.min(sc), np.max(sc),\
                    np.mean(sb), np.std(sb), np.min(sb), np.max(sb),\
                    np.mean(sfs), np.std(sfs), np.min(sfs), np.max(sfs)]

        # Calcul des fréquences pour chaque point de la FFT
        frequences = lr.fft_frequencies(sr=sr, n_fft=n_fft) #Permet de récupérer les fréquences possibles

        # Calcul de la médiane sur l'axe temporel associé à chaque fenêtre + tronquage 
        median = np.median(tf_sig, axis=1)[(fm<frequences) & (frequences<fM)]
        frequences = frequences[(fm<frequences) & (frequences<fM)]

        loc = path[115:-4] #Pour récupérer la localisation de l'audio 

        if display:
            # Affichage du signal
            # Créer le temps (axe x)
            time = np.linspace(1/sr,duration,n_frames)
            plt.figure(figsize=(12, 6))
            plt.plot(time,audio, label="Canal 1")
            plt.title(f"Visualisation Audio {path[110:-4]}")
            plt.xlabel("Temps (s)")
            plt.ylabel("Amplitude")
            plt.legend()
            plt.show()

            # Tracer le spectre avec les fréquences en abscisses
            plt.figure(figsize=(10,10))
            plt.plot(frequences, median,c='g')
            plt.xlabel('Fréquence (Hz)')
            plt.ylabel('Amplitude en Db')
            plt.title(f'Spectre médian tronqué du signal sur une fenêtre glissante de {n_fft} samples')
            plt.show()

        return sr, duration, median, loc, features
    else:
        print("Le fichier suivant n'est pas au format .wav",path)

def recup_freq(path,fm = 1e3,fM=1e5,n_fft=1000):
    """
    Cette fonction permet de récupérer les fréquences 
    """
    sr = sf.read(path)[1] #audio est un array et sr est la freq d'echantillonnage
    
    # récupère les fréquences pour chaque point de la FFT
    frequences = lr.fft_frequencies(sr=sr, n_fft=n_fft)
    frequences = frequences[(fm<frequences) & (frequences<fM)]
    return frequences

sr, duration, median, loc, features = visual_audio(os.path.join(path,'01105-JAM.wav'),display=True,fm = fm,fM=fM,n_fft=n_fft)

frequences = recup_freq(os.path.join(path,'01105-JAM.wav'),fm = fm,fM=fM,n_fft=n_fft)

# %%
print(median.shape,frequences.shape)
# Out:
# (935,) (935,)

# %% [markdown]
# ## Visualisation de plusieurs audios pour voir l'allure

# %%
list1 = ["01670-JAM.wav","01671-JAM.wav","01672-JAM.wav","01673-JAM.wav","01674-JAM.wav","01675-JAM.wav","01676-JAM.wav","01677-JAM.wav","01678-JAM.wav","01679-JAM.wav","01680-JAM.wav","01681-JAM.wav","01682-JAM.wav","01683-JAM.wav","01684-JAM.wav"]
list2 = ["00411-BON.wav",\
"00412-BON.wav",\
"00413-BON.wav",\
"00414-BON.wav",\
"00415-BON.wav",\
"00416-BON.wav",\
"00417-BON.wav"]

for audio in list2:
    visual_audio(os.path.join(path,audio))

# %% [markdown]
# ## tester l'homogénéité des données et récupérer des features intéressantes

# %%
dico1 = {}
for ech in os.listdir(path):
    dico1[f"{ech}"] = visual_audio(os.path.join(path,ech),display=False,fm = fm,fM=fM,n_fft=n_fft)
    if dico1[f"{ech}"] == None:
        dico1.pop(f"{ech}")
# Out:
# Le fichier suivant n'est pas au format .wav /home/ibotcazou/Bureau/Master_data_science/DATAS_M2/Apprentissage_Statistique_Panloup/Data_challenge/X_train/.DS_Store

# %%
dicotest = {}
for ech in os.listdir(path_test):
    dicotest[f"{ech}"] = visual_audio(os.path.join(path_test,ech),display=False,fm = fm,fM=fM,n_fft=n_fft)
    if dicotest[f"{ech}"] == None:
        dicotest.pop(f"{ech}")
# Out:
# Le fichier suivant n'est pas au format .wav /home/ibotcazou/Bureau/Master_data_science/DATAS_M2/Apprentissage_Statistique_Panloup/Data_challenge/X__test/.DS_Store
# Le fichier suivant n'est pas au format .wav /home/ibotcazou/Bureau/Master_data_science/DATAS_M2/Apprentissage_Statistique_Panloup/Data_challenge/X__test/.zip

# %%
for key in dico1.keys():
    c=0
    if (dico1[str(key)][0]!=256000) | (dico1[str(key)][1]!=0.2):
        print(key)
        c+=1
print(f"Il y a {c} fichiers non conformes dans le fichier train ")

for key in dicotest.keys():
    c=0
    if (dicotest[str(key)][0]!=256000) | (dicotest[str(key)][1]!=0.2):
        print(key)
        c+=1
print(f"Il y a {c} fichiers non conformes dans le fichier test")
# Out:
# Il y a 0 fichiers non conformes dans le fichier train
# Il y a 0 fichiers non conformes dans le fichier test

# %% [markdown]
# ## Ajout de la variable target et création d'un data frame, export un csv

# %%
Y_train = pd.read_csv(path_Y)
f = lambda x:x[6:-4]
Y_train['loc'] = Y_train['id'].apply(f)
Y_train
# Out:
#                        id  pos_label       loc
# 0           00000-JAM.wav        0.0       JAM
# 1           00001-JAM.wav        1.0       JAM
# 2           00002-JAM.wav        1.0       JAM
# 3           00003-JAM.wav        1.0       JAM
# 4           00004-JAM.wav        1.0       JAM
# ...                   ...        ...       ...
# 23163  23163-StMARTIN.wav        0.0  StMARTIN
# 23164  23164-StMARTIN.wav        0.0  StMARTIN
# 23165  23165-StMARTIN.wav        0.0  StMARTIN
# 23166  23166-StMARTIN.wav        0.0  StMARTIN
# 23167  23167-StMARTIN.wav        0.0  StMARTIN
#
# [23168 rows x 3 columns]

# %% [markdown]
# ## Data train

# %%
columns_names = ["id","target"] + list(frequences) + ["rms.mean","rms.std","rms.min","rms.max","sc.mean","sc.std","sc.min","sc.max","sb.mean","sb.std","sb.min","sb.max","sfs.mean","sfs.std","sfs.min","sfs.max"]

data = []
for i in Y_train.index:
    data_i = [ Y_train.iloc[i]["id"],Y_train.iloc[i]["pos_label"]]
    data_i = data_i + list(dico1[Y_train.iloc[i]["id"]][2]) + dico1[Y_train.iloc[i]["id"]][4]
    data.append(data_i)

df = pd.DataFrame(data,columns=columns_names)

# %% [markdown]
# ## Data validation

# %%
columns_test_names = ["id"] +list(frequences) + ["rms.mean","rms.std","rms.min","rms.max","sc.mean","sc.std","sc.min","sc.max","sb.mean","sb.std","sb.min","sb.max","sfs.mean","sfs.std","sfs.min","sfs.max"]

data_test = []

for key in dicotest.keys():
    data_i = [key]
    data_i = data_i + list(dicotest[key][2]) + dicotest[key][4]
    data_test.append(data_i)

df_test = pd.DataFrame(data_test,columns=columns_test_names)

# %%
df_test.shape
# Out:
# (950, 952)

# %%
df.to_csv("/home/ibotcazou/Bureau/Master_data_science/DATAS_M2/Apprentissage_Statistique_Panloup/Data_challenge/features950_data.csv")
df_test.to_csv("/home/ibotcazou/Bureau/Master_data_science/DATAS_M2/Apprentissage_Statistique_Panloup/Data_challenge/test_features950_data.csv")

# %% [markdown]
# # Machine learning

# %% [markdown]
# ## Preprocessing du DataFrame

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

from sklearn.model_selection import train_test_split

from sklearn.metrics import accuracy_score,f1_score # pour voir l'efficacité globale du modèle
from sklearn.metrics import confusion_matrix,classification_report
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve, auc

#dataset train
df = pd.read_csv("/home/ibotcazou/Bureau/Master_data_science/DATAS_M2/Apprentissage_Statistique_Panloup/Data_challenge/features_data.csv",index_col=0)
df.index = range(1,len(df)+1)

#data validation
df_test = pd.read_csv("/home/ibotcazou/Bureau/Master_data_science/DATAS_M2/Apprentissage_Statistique_Panloup/Data_challenge/test_features_data.csv",index_col='id')
df_test = df_test.iloc[:,1:]

#slpit des données train 
trainset, testset = train_test_split(df, test_size=0.2,random_state=0)

def preprocessing(dataframe):
    """
    Fonction qui retourne les features et la target séparément
    """
    return dataframe.drop('target',axis=1), dataframe.target

X_train,Y_train = preprocessing(trainset)
X_test,Y_test = preprocessing(testset)

# %% [markdown]
# ## Arbres de decision

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

from sklearn.model_selection import learning_curve # utile pour voir comment rajouter des données améliore le modèle

# %% [markdown]
# ### Équilibre des classes

# %%
print(trainset.target.value_counts()/trainset.target.shape[0])
print(testset.target.value_counts()/testset.target.shape[0])
# Out:
# target
# 0.0    0.589673
# 1.0    0.410327
# Name: count, dtype: float64
# target
# 0.0    0.601856
# 1.0    0.398144
# Name: count, dtype: float64

# %%
    
def evaluation_model(model,X_train,X_test,Y_train,Y_test,lc=True):
    """
    Cette fonction permet d'entraîner un modèle du type arbre  et d'en évaluer la performance sur un testset
    """
    
    model.fit(X_train,Y_train)
    
    Y_pred = model.predict(X_test)
    # Prédire les probabilités pour la classe positive
    Y_proba_pred = model.predict_proba(X_test)

    # Calculer les scores TPR (True Positive Rate) et FPR (False Positive Rate)
    fpr, tpr, thresholds = roc_curve(Y_test, Y_proba_pred[:,1])
          
        
    matrix_conf = confusion_matrix(Y_test,Y_pred)
    print(classification_report(Y_test,Y_pred))
    
    plt.figure(figsize=(5,5))
    sns.heatmap(matrix_conf,annot=True,fmt='g')
    plt.title('Matrice de confusion')
    plt.xlabel('Prédictions')
    plt.ylabel('Valeurs réelles')
    plt.show()

    if lc:
        N,train_score,val_score = learning_curve(model,X_train,Y_train,cv=4,train_sizes=np.linspace(0.1,1,10),scoring="f1") 
        #calcule les différents score avec de la cross validation pour des entrainements de plus en plus grand en données 
        # Ici le Val score est un morceau des données train
        plt.figure(figsize=(8,8))
        plt.plot(N,train_score.mean(axis=1),label="train score")
        plt.plot(N,val_score.mean(axis=1),label="train score")
        plt.legend()
        plt.show()

    # Calculer l'aire sous la courbe ROC (AUC)
    roc_auc = auc(fpr, tpr)

    # Tracer la courbe ROC
    plt.figure()
    plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (area = {roc_auc:.6f})') # aire sous la courbe
    plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Courbe ROC (Receiver Operating Characteristic)')
    plt.legend(loc="lower right")
    plt.show()

# %% [markdown]
# ## Premier modèle naïf

# %%
tree1 = DecisionTreeClassifier(random_state=0)

evaluation_model(tree1,X_train,X_test,Y_train,Y_test)
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.95      0.95      2789
#          1.0       0.92      0.92      0.92      1845
#
#     accuracy                           0.94      4634
#    macro avg       0.93      0.93      0.93      4634
# weighted avg       0.94      0.94      0.94      4634

# %% [markdown]
# On voit que notre modèle est en overfitting car il est parfait sur les données train mais pas sur les données testé avec la cross validation. On remarque cependant que donner plus de données à notre modèle le fait progresser.

# %%
pd.DataFrame(tree1.feature_importances_,index=X_train.columns).plot.bar(figsize=(12,12),title='Importance des variables pour ce modèle')
# Out:
# <AxesSubplot:title={'center':'Importance des variables pour ce modèle'}>

# %% [markdown]
# ## Une Random forest

# %%
# Créer le modèle DecisionTreeClassifier
forest_tree = RandomForestClassifier(random_state=0)

# Entraîner le modèle
evaluation_model(forest_tree ,X_train,X_test,Y_train,Y_test)
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.98      0.97      0.97      2789
#          1.0       0.96      0.96      0.96      1845
#
#     accuracy                           0.97      4634
#    macro avg       0.97      0.97      0.97      4634
# weighted avg       0.97      0.97      0.97      4634

# %%
pd.DataFrame(forest_tree.feature_importances_,index=X_train.columns).plot.bar(figsize=(12,12),title='Importance des variables pour ce modèle')
# Out:
# <AxesSubplot:title={'center':'Importance des variables pour ce modèle'}>

# %% [markdown]
# ### Soumission1 modèle random forest

# %%
plt.hist(forest_tree.predict_proba(X_test)[:,1],100,density=False,label='proba de test')
plt.grid()
plt.legend()
plt.title("Histogram sur les données test")
plt.show()


plt.hist(forest_tree.predict_proba(df_test)[:,1],100,density=False,label='proba de validation')
plt.grid()
plt.legend()
plt.show()

# %%
df_soumission1 = df_test.drop(df_test.columns,axis = 1)
df_soumission1['pos_label'] = forest_tree.predict_proba(df_test)[:,1]
df_soumission1.to_csv("/home/ibotcazou/Bureau/Master_data_science/DATAS_M2/Apprentissage_Statistique_Panloup/Data_challenge/soumission1.csv")

# %% [markdown]
# ## Make a Pipeline avec de la random Forest et des features polynomiales

# %%
from sklearn.pipeline import make_pipeline
from sklearn.feature_selection import SelectKBest, f_classif #Choisir les meilleurs varialbles avec un test d'Anova
from sklearn.preprocessing import PolynomialFeatures

# %%
model = make_pipeline(SelectKBest(f_classif,k=25),                      
                      RandomForestClassifier(random_state=0))

# Entraîner le modèle
evaluation_model(model ,X_train,X_test,Y_train,Y_test,lc=False)
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.97      0.96      2789
#          1.0       0.95      0.94      0.95      1845
#
#     accuracy                           0.96      4634
#    macro avg       0.96      0.95      0.96      4634
# weighted avg       0.96      0.96      0.96      4634

# %%
plt.hist(model.predict_proba(X_test)[:,1],100,color='g',density=False,label='proba de test')
plt.grid()
plt.legend()
plt.title("Histogram sur les données test")
plt.show()


plt.hist(model.predict_proba(df_test)[:,1],100,density=False,label='proba de validation')
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# ### Soumission2 make a pipeline, ACP et Random forest

# %%
df_soumission2 = df_test.drop(df_test.columns,axis = 1)
df_soumission2['pos_label'] = model.predict_proba(df_test)[:,1]
df_soumission2.to_csv("/home/ibotcazou/Bureau/Master_data_science/DATAS_M2/Apprentissage_Statistique_Panloup/Data_challenge/soumission2.csv")

# %% [markdown]
# # Deep learning

# %%
## Preprocessing du DataFrame

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

from sklearn.model_selection import train_test_split

from sklearn.metrics import accuracy_score,f1_score # pour voir l'efficacité globale du modèle
from sklearn.metrics import confusion_matrix,classification_report
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve, auc

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam
# Out:
# 2024-01-18 16:13:30.590395: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-01-18 16:13:31.089335: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-01-18 16:13:31.089484: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-01-18 16:13:31.170825: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-01-18 16:13:31.359460: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-01-18 16:13:31.363576: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-01-18 16:13:33.008099: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
    
def evaluation_model(model,X_train,X_test,Y_train,Y_test, batch_size=20, epochs=80,lr=0.001):
    """
    Cette fonction entraîne une modèle de réseau de neurones de classification binaire pour ensuite l'évaluer sur des données test 
    L'algorithme d'optimisation de l'apprentissage est Adam  
    """
    
    #Pour stopper quand les courbes de coût se croisent
    earlystopping = EarlyStopping(monitor='val_loss', patience=10, verbose=1)

    #Paramètre du learning rate pour l'algorithme Adam
    adam_optimizer = Adam(learning_rate=lr)

    # Compilateur du modèle avec le nouvel optimiseur
    model.compile(loss='binary_crossentropy', optimizer=adam_optimizer, metrics=['accuracy'])
    
    #garder en mémoire l'apprentissage
    history =  model.fit(X_train, Y_train, batch_size=batch_size, epochs=epochs, validation_data=(X_test,Y_test),callbacks=[earlystopping] )

    # Prédire les probabilités pour la classe positive
    Y_proba_pred = model.predict(X_test)

    # Calculer les scores TPR (True Positive Rate) et FPR (False Positive Rate)
    fpr, tpr, thresholds = roc_curve(Y_test, Y_proba_pred)

    #Trouver le bon indice pour le seuil de décision, au milieu de la courbe Roc
    indice = int(np.floor(len(thresholds)/2))
    print( "voici le seuil médian" ,thresholds[indice-1])

    # Calculer l'aire sous la courbe ROC (AUC)
    roc_auc = auc(fpr, tpr)

    #Prédiction sur le seuil précédent
    Y_pred = Y_proba_pred > thresholds[indice-1]
    
    #Rapport de classification  
    matrix_conf = confusion_matrix(Y_test,Y_pred)
    print(classification_report(Y_test,Y_pred))

    ##Matrice de confusion 
    plt.figure(figsize=(5,5))
    sns.heatmap(matrix_conf,annot=True,fmt='g')
    plt.title('Matrice de confusion')
    plt.xlabel('Prédictions')
    plt.ylabel('Valeurs réelles')
    plt.show()

    ##Historique de l'apprentissage

    #Score
    plt.figure(figsize=(15,15))
    plt.subplot(1,2,1)
    plt.plot(history.history['accuracy'], label='Accuracy (training data)')
    plt.plot(history.history['val_accuracy'], label='Accuracy (validation data)')
    plt.title('Accuracy over epochs')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend()
    #Loss
    plt.subplot(1,2,2)
    plt.plot(history.history['loss'], label='loss (training data)')
    plt.plot(history.history['val_loss'], label='loss(validation data)')
    plt.title('Loss over epochs')
    plt.ylabel('loss')
    plt.xlabel('Epoch')
    plt.legend()
    plt.show()

    # Tracer la courbe ROC
    plt.figure()
    plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (area = {roc_auc:.6f})') # aire sous la courbe
    plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Courbe ROC (Receiver Operating Characteristic)')
    plt.legend(loc="lower right")
    plt.show()

# %% [markdown]
# ## Un réseau de neurones multicouches

# %% [markdown]
# ### Standardisation des données

# %%
df = pd.read_csv("/home/ibotcazou/Bureau/Master_data_science/DATAS_M2/Apprentissage_Statistique_Panloup/Data_challenge/features_data.csv",index_col=0)
df.index = range(1,23169)
df_std = df.copy()

df_test = pd.read_csv("/home/ibotcazou/Bureau/Master_data_science/DATAS_M2/Apprentissage_Statistique_Panloup/Data_challenge/test_features_data.csv",index_col='id')
df_test = df_test.iloc[:,1:]
df_test_std = df_test.copy()

#Standardisation des données
df_std.iloc[:,1:] = (df_std.iloc[:,1:] - df_std.iloc[:,1:].mean(axis=0))/df_std.iloc[:,1:].std(axis=0)
df_test_std = (df_test_std - df_test_std.mean(axis=0) )/ df_test_std.std(axis=0)

trainset, testset = train_test_split(df_std, test_size=0.2,random_state=0)

def preprocessing(dataframe):
    return dataframe.drop('target',axis=1), dataframe.target

X_train,Y_train = preprocessing(trainset)
X_test,Y_test = preprocessing(testset)

# %%
X_train
# Out:
#          5120.0    5632.0    6144.0    6656.0    7168.0    7680.0    8192.0  \
# 14714  0.314585  0.567127  0.497398  0.632767  0.635438  0.343430  0.206735
# 22766 -0.279047 -0.150175 -0.141035 -0.103095 -0.158307  0.007323 -0.033879
# 15055  0.342820  0.606136  0.643781  0.934973  0.784519  0.535906  0.519194
# 12613 -0.655397 -0.701079 -0.741630 -0.742450 -0.680815 -0.805033 -0.795378
# 6286  -0.529578 -0.634100 -0.646681 -0.626867 -0.586255 -0.605662 -0.616391
# ...         ...       ...       ...       ...       ...       ...       ...
# 13124 -0.623771 -0.651961 -0.628589 -0.654749 -0.412814 -0.348451 -0.279954
# 19649  2.013543  1.124911  0.435919  0.410726  0.645797  0.264039  0.248527
# 9846   2.084921  1.292841 -0.677139 -0.567109 -0.719195 -0.511676 -0.653289
# 10800 -0.591112 -0.509493 -0.535144 -0.559369 -0.513102 -0.523211 -0.519523
# 2733   6.472178  5.496630  6.572350  5.509955  3.438140  1.432005  1.151637
#
#          8704.0    9216.0    9728.0  ...    sc.min    sc.max   sb.mean  \
# 14714  0.359481  0.282247  0.064285  ...  0.324120  0.843605  0.586475
# 22766  0.402535  0.387660  0.219651  ...  0.942626 -0.466895  0.722880
# 15055  0.742698  0.545135  0.162142  ... -0.068900  1.255371  0.044605
# 12613 -0.904526 -0.739233 -0.655454  ...  0.831983  0.493039  0.440323
# 6286  -0.737111 -0.609664 -0.620415  ...  0.642381 -0.468137  0.447916
# ...         ...       ...       ...  ...       ...       ...       ...
# 13124 -0.017026  0.125488  0.583038  ...  0.708744 -0.349322 -0.146936
# 19649  0.542587  1.674815  2.611551  ...  0.049048 -0.795875 -0.358754
# 9846  -0.829263 -0.814204 -0.364388  ... -0.103862  1.726724 -0.018995
# 10800 -0.568357 -0.556322 -0.663701  ...  0.511632  2.581054  0.206433
# 2733   1.107081  0.513244 -0.062242  ... -6.259462 -2.179254 -3.502744
#
#          sb.std    sb.min    sb.max  sfs.mean   sfs.std   sfs.min   sfs.max
# 14714  0.013715 -0.196981 -0.029097  0.236200 -0.007373  0.136434 -0.052309
# 22766 -0.000505  0.306931  0.393846  0.053122  0.062083  0.790364  0.282435
# 15055 -0.028070  0.096113  0.463660  0.092396 -0.134285 -0.449815 -0.321972
# 12613 -0.235342 -0.258978 -0.593659  0.403702  0.073228  2.196431  0.569836
# 6286  -0.133331  0.326426  0.382031 -0.010296 -0.051283  0.056569  0.061842
# ...         ...       ...       ...       ...       ...       ...       ...
# 13124  0.396920 -0.144146 -0.542791  0.032807 -0.105303  1.153321  0.021669
# 19649 -0.176893 -0.127384  0.433623 -0.067038 -0.007011  0.058878  0.262710
# 9846  -0.365531  0.249188 -0.440646 -0.254034  0.072571 -0.265869  0.354832
# 10800 -0.092499  0.001852 -0.476629 -0.048447  0.038749  0.139681  0.178001
# 2733   3.825367 -6.929486 -0.724507 -0.843292 -0.213786 -2.572128 -0.648299
#
# [18534 rows x 202 columns]

# %% [markdown]
# ## first neuronal network

# %%
neuronal_network = Sequential()
neuronal_network.add(Dense(21,input_dim=X_train.shape[1], activation='swish'))  # input_shape doit correspondre à la forme de vos données d'entrée
neuronal_network.add(Dropout(0.25))

neuronal_network.add(Dense(63, activation='swish'))  # input_shape doit correspondre à la forme de vos données d'entrée
neuronal_network.add(Dropout(0.25))

neuronal_network.add(Dense(189, activation='swish'))  # input_shape doit correspondre à la forme de vos données d'entrée
neuronal_network.add(Dropout(0.25))

neuronal_network.add(Dense(567, activation='swish'))  # input_shape doit correspondre à la forme de vos données d'entrée
neuronal_network.add(Dropout(0.5))

neuronal_network.add(Dense(189, activation='swish'))  # input_shape doit correspondre à la forme de vos données d'entrée
neuronal_network.add(Dropout(0.25))

neuronal_network.add(Dense(1, activation='sigmoid'))  # Sortie binaire

evaluation_model(neuronal_network,X_train,X_test,Y_train,Y_test, batch_size=200, epochs=140,lr=0.0001)
#batch_size est le nombre d'individus utilisés pour la descente de gradient lors du Mini Bach
# 1 epoch est égale à N/batch_sige  fois ou on fait tourner l'algo
# Out:
# Epoch 1/140
# 93/93 [==============================] - 3s 12ms/step - loss: 0.6771 - accuracy: 0.6150 - val_loss: 0.6430 - val_accuracy: 0.6724
# Epoch 2/140
# 93/93 [==============================] - 1s 12ms/step - loss: 0.5902 - accuracy: 0.7258 - val_loss: 0.4851 - val_accuracy: 0.8228
# Epoch 3/140
# 93/93 [==============================] - 1s 14ms/step - loss: 0.4573 - accuracy: 0.8067 - val_loss: 0.3875 - val_accuracy: 0.8498
# Epoch 4/140
# 93/93 [==============================] - 1s 13ms/step - loss: 0.3940 - accuracy: 0.8392 - val_loss: 0.3405 - val_accuracy: 0.8712
# Epoch 5/140
# 93/93 [==============================] - 1s 12ms/step - loss: 0.3624 - accuracy: 0.8543 - val_loss: 0.3190 - val_accuracy: 0.8794
# Epoch 6/140
# 93/93 [==============================] - 1s 12ms/step - loss: 0.3426 - accuracy: 0.8644 - val_loss: 0.3030 - val_accuracy: 0.8863
# Epoch 7/140
# 93/93 [==============================] - 1s 10ms/step - loss: 0.3259 - accuracy: 0.8731 - val_loss: 0.2904 - val_accuracy: 0.8912
# Epoch 8/140
# 93/93 [==============================] - 1s 9ms/step - loss: 0.3161 - accuracy: 0.8758 - val_loss: 0.2805 - val_accuracy: 0.8943
# Epoch 9/140
# 93/93 [==============================] - 1s 10ms/step - loss: 0.3064 - accuracy: 0.8814 - val_loss: 0.2722 - val_accuracy: 0.8971
# Epoch 10/140
# 93/93 [==============================] - 1s 10ms/step - loss: 0.2981 - accuracy: 0.8851 - val_loss: 0.2668 - val_accuracy: 0.9014
# Epoch 11/140
# 93/93 [==============================] - 1s 10ms/step - loss: 0.2917 - accuracy: 0.8901 - val_loss: 0.2643 - val_accuracy: 0.9035
# Epoch 12/140
# 93/93 [==============================] - 1s 10ms/step - loss: 0.2885 - accuracy: 0.8882 - val_loss: 0.2566 - val_accuracy: 0.9066
# Epoch 13/140
# 93/93 [==============================] - 1s 10ms/step - loss: 0.2824 - accuracy: 0.8919 - val_loss: 0.2529 - val_accuracy: 0.9083
# Epoch 14/140
# 93/93 [==============================] - 1s 10ms/step - loss: 0.2779 - accuracy: 0.8954 - val_loss: 0.2452 - val_accuracy: 0.9100
# Epoch 15/140
# 93/93 [==============================] - 1s 10ms/step - loss: 0.2741 - accuracy: 0.8976 - val_loss: 0.2436 - val_accuracy: 0.9126
# Epoch 16/140
# 93/93 [==============================] - 1s 11ms/step - loss: 0.2655 - accuracy: 0.8995 - val_loss: 0.2397 - val_accuracy: 0.9130
# Epoch 17/140
# 93/93 [==============================] - 1s 12ms/step - loss: 0.2604 - accuracy: 0.9010 - val_loss: 0.2372 - val_accuracy: 0.9152
# Epoch 18/140
# 93/93 [==============================] - 1s 11ms/step - loss: 0.2595 - accuracy: 0.9005 - val_loss: 0.2377 - val_accuracy: 0.9165
# Epoch 19/140
# 93/93 [==============================] - 1s 10ms/step - loss: 0.2573 - accuracy: 0.9030 - val_loss: 0.2292 - val_accuracy: 0.9191
# Epoch 20/140
# 93/93 [==============================] - 1s 11ms/step - loss: 0.2529 - accuracy: 0.9072 - val_loss: 0.2285 - val_accuracy: 0.9186
# Epoch 21/140
# 93/93 [==============================] - 1s 10ms/step - loss: 0.2466 - accuracy: 0.9067 - val_loss: 0.2264 - val_accuracy: 0.9171
# Epoch 22/140
# 93/93 [==============================] - 1s 10ms/step - loss: 0.2501 - accuracy: 0.9051 - val_loss: 0.2214 - val_accuracy: 0.9206
# Epoch 23/140
# 93/93 [==============================] - 1s 11ms/step - loss: 0.2467 - accuracy: 0.9095 - val_loss: 0.2202 - val_accuracy: 0.9189
# Epoch 24/140
# 93/93 [==============================] - 1s 11ms/step - loss: 0.2437 - accuracy: 0.9089 - val_loss: 0.2183 - val_accuracy: 0.9230
# Epoch 25/140
# 93/93 [==============================] - 1s 11ms/step - loss: 0.2410 - accuracy: 0.9120 - val_loss: 0.2152 - val_accuracy: 0.9227
# Epoch 26/140
# 93/93 [==============================] - 1s 11ms/step - loss: 0.2358 - accuracy: 0.9117 - val_loss: 0.2169 - val_accuracy: 0.9245
# Epoch 27/140
# 93/93 [==============================] - 1s 10ms/step - loss: 0.2338 - accuracy: 0.9123 - val_loss: 0.2107 - val_accuracy: 0.9240
# Epoch 28/140
# 93/93 [==============================] - 1s 9ms/step - loss: 0.2327 - accuracy: 0.9147 - val_loss: 0.2088 - val_accuracy: 0.9271
# Epoch 29/140
# 93/93 [==============================] - 1s 10ms/step - loss: 0.2375 - accuracy: 0.9097 - val_loss: 0.2096 - val_accuracy: 0.9271
# Epoch 30/140
# 93/93 [==============================] - 1s 9ms/step - loss: 0.2302 - accuracy: 0.9144 - val_loss: 0.2061 - val_accuracy: 0.9277
# Epoch 31/140
# 93/93 [==============================] - 1s 9ms/step - loss: 0.2281 - accuracy: 0.9148 - val_loss: 0.2071 - val_accuracy: 0.9275
# Epoch 32/140
# 93/93 [==============================] - 1s 10ms/step - loss: 0.2251 - accuracy: 0.9164 - val_loss: 0.2040 - val_accuracy: 0.9290
# Epoch 33/140
# 93/93 [==============================] - 1s 10ms/step - loss: 0.2267 - accuracy: 0.9164 - val_loss: 0.2040 - val_accuracy: 0.9284
# Epoch 34/140
# 93/93 [==============================] - 1s 10ms/step - loss: 0.2223 - accuracy: 0.9176 - val_loss: 0.2019 - val_accuracy: 0.9284
# Epoch 35/140
# 93/93 [==============================] - 1s 11ms/step - loss: 0.2240 - accuracy: 0.9149 - val_loss: 0.2016 - val_accuracy: 0.9292
# Epoch 36/140
# 93/93 [==============================] - 1s 11ms/step - loss: 0.2191 - accuracy: 0.9201 - val_loss: 0.2012 - val_accuracy: 0.9320
# Epoch 37/140
# 93/93 [==============================] - 1s 13ms/step - loss: 0.2171 - accuracy: 0.9184 - val_loss: 0.1995 - val_accuracy: 0.9288
# Epoch 38/140
# 93/93 [==============================] - 1s 13ms/step - loss: 0.2186 - accuracy: 0.9207 - val_loss: 0.1970 - val_accuracy: 0.9299
# Epoch 39/140
# 93/93 [==============================] - 1s 15ms/step - loss: 0.2164 - accuracy: 0.9214 - val_loss: 0.1959 - val_accuracy: 0.9305
# Epoch 40/140
# 93/93 [==============================] - 1s 12ms/step - loss: 0.2149 - accuracy: 0.9206 - val_loss: 0.1950 - val_accuracy: 0.9322
# Epoch 41/140
# 93/93 [==============================] - 1s 11ms/step - loss: 0.2145 - accuracy: 0.9204 - val_loss: 0.1927 - val_accuracy: 0.9314
# Epoch 42/140
# 93/93 [==============================] - 1s 11ms/step - loss: 0.2127 - accuracy: 0.9241 - val_loss: 0.1914 - val_accuracy: 0.9331
# Epoch 43/140
# 93/93 [==============================] - 1s 11ms/step - loss: 0.2139 - accuracy: 0.9228 - val_loss: 0.1911 - val_accuracy: 0.9335
# Epoch 44/140
# 93/93 [==============================] - 1s 12ms/step - loss: 0.2092 - accuracy: 0.9239 - val_loss: 0.1886 - val_accuracy: 0.9344
# Epoch 45/140
# 93/93 [==============================] - 1s 12ms/step - loss: 0.2083 - accuracy: 0.9236 - val_loss: 0.1891 - val_accuracy: 0.9340
# Epoch 46/140
# 93/93 [==============================] - 2s 21ms/step - loss: 0.2073 - accuracy: 0.9235 - val_loss: 0.1900 - val_accuracy: 0.9353
# Epoch 47/140
# 93/93 [==============================] - 2s 21ms/step - loss: 0.2035 - accuracy: 0.9259 - val_loss: 0.1875 - val_accuracy: 0.9342
# Epoch 48/140
# 93/93 [==============================] - 2s 20ms/step - loss: 0.2076 - accuracy: 0.9244 - val_loss: 0.1862 - val_accuracy: 0.9335
# Epoch 49/140
# 93/93 [==============================] - 2s 17ms/step - loss: 0.2055 - accuracy: 0.9258 - val_loss: 0.1893 - val_accuracy: 0.9344
# Epoch 50/140
# 93/93 [==============================] - 1s 16ms/step - loss: 0.2024 - accuracy: 0.9253 - val_loss: 0.1842 - val_accuracy: 0.9353
# Epoch 51/140
# 93/93 [==============================] - 2s 20ms/step - loss: 0.2046 - accuracy: 0.9245 - val_loss: 0.1834 - val_accuracy: 0.9357
# Epoch 52/140
# 93/93 [==============================] - 1s 15ms/step - loss: 0.1999 - accuracy: 0.9269 - val_loss: 0.1824 - val_accuracy: 0.9355
# Epoch 53/140
# 93/93 [==============================] - 1s 14ms/step - loss: 0.2032 - accuracy: 0.9255 - val_loss: 0.1828 - val_accuracy: 0.9355
# Epoch 54/140
# 93/93 [==============================] - 2s 18ms/step - loss: 0.1966 - accuracy: 0.9273 - val_loss: 0.1803 - val_accuracy: 0.9370
# Epoch 55/140
# 93/93 [==============================] - 1s 16ms/step - loss: 0.1974 - accuracy: 0.9283 - val_loss: 0.1791 - val_accuracy: 0.9361
# Epoch 56/140
# 93/93 [==============================] - 1s 14ms/step - loss: 0.1982 - accuracy: 0.9271 - val_loss: 0.1789 - val_accuracy: 0.9370
# Epoch 57/140
# 93/93 [==============================] - 1s 12ms/step - loss: 0.1987 - accuracy: 0.9272 - val_loss: 0.1797 - val_accuracy: 0.9366
# Epoch 58/140
# 93/93 [==============================] - 1s 12ms/step - loss: 0.1970 - accuracy: 0.9287 - val_loss: 0.1815 - val_accuracy: 0.9361
# Epoch 59/140
# 93/93 [==============================] - 1s 12ms/step - loss: 0.1945 - accuracy: 0.9279 - val_loss: 0.1792 - val_accuracy: 0.9368
# Epoch 60/140
# 93/93 [==============================] - 1s 11ms/step - loss: 0.1949 - accuracy: 0.9288 - val_loss: 0.1763 - val_accuracy: 0.9379
# Epoch 61/140
# 93/93 [==============================] - 1s 12ms/step - loss: 0.1939 - accuracy: 0.9290 - val_loss: 0.1752 - val_accuracy: 0.9381
# Epoch 62/140
# 93/93 [==============================] - 1s 11ms/step - loss: 0.1971 - accuracy: 0.9279 - val_loss: 0.1748 - val_accuracy: 0.9383
# Epoch 63/140
# 93/93 [==============================] - 1s 12ms/step - loss: 0.1899 - accuracy: 0.9309 - val_loss: 0.1753 - val_accuracy: 0.9387
# Epoch 64/140
# 93/93 [==============================] - 1s 11ms/step - loss: 0.1913 - accuracy: 0.9286 - val_loss: 0.1760 - val_accuracy: 0.9407
# Epoch 65/140
# 93/93 [==============================] - 1s 11ms/step - loss: 0.1902 - accuracy: 0.9315 - val_loss: 0.1757 - val_accuracy: 0.9394
# Epoch 66/140
# 93/93 [==============================] - 1s 11ms/step - loss: 0.1858 - accuracy: 0.9330 - val_loss: 0.1718 - val_accuracy: 0.9396
# Epoch 67/140
# 93/93 [==============================] - 1s 11ms/step - loss: 0.1891 - accuracy: 0.9302 - val_loss: 0.1716 - val_accuracy: 0.9396
# Epoch 68/140
# 93/93 [==============================] - 1s 11ms/step - loss: 0.1861 - accuracy: 0.9325 - val_loss: 0.1705 - val_accuracy: 0.9391
# Epoch 69/140
# 93/93 [==============================] - 1s 11ms/step - loss: 0.1889 - accuracy: 0.9314 - val_loss: 0.1740 - val_accuracy: 0.9400
# Epoch 70/140
# 93/93 [==============================] - 1s 11ms/step - loss: 0.1870 - accuracy: 0.9313 - val_loss: 0.1687 - val_accuracy: 0.9407
# Epoch 71/140
# 93/93 [==============================] - 1s 11ms/step - loss: 0.1863 - accuracy: 0.9304 - val_loss: 0.1700 - val_accuracy: 0.9402
# Epoch 72/140
# 93/93 [==============================] - 1s 10ms/step - loss: 0.1862 - accuracy: 0.9320 - val_loss: 0.1672 - val_accuracy: 0.9402
# Epoch 73/140
# 93/93 [==============================] - 1s 10ms/step - loss: 0.1817 - accuracy: 0.9346 - val_loss: 0.1666 - val_accuracy: 0.9413
# Epoch 74/140
# 93/93 [==============================] - 1s 10ms/step - loss: 0.1837 - accuracy: 0.9339 - val_loss: 0.1705 - val_accuracy: 0.9402
# Epoch 75/140
# 93/93 [==============================] - 1s 11ms/step - loss: 0.1841 - accuracy: 0.9324 - val_loss: 0.1668 - val_accuracy: 0.9404
# Epoch 76/140
# 93/93 [==============================] - 1s 11ms/step - loss: 0.1821 - accuracy: 0.9335 - val_loss: 0.1672 - val_accuracy: 0.9417
# Epoch 77/140
# 93/93 [==============================] - 1s 11ms/step - loss: 0.1827 - accuracy: 0.9329 - val_loss: 0.1642 - val_accuracy: 0.9413
# Epoch 78/140
# 93/93 [==============================] - 1s 12ms/step - loss: 0.1804 - accuracy: 0.9346 - val_loss: 0.1647 - val_accuracy: 0.9413
# Epoch 79/140
# 93/93 [==============================] - 1s 11ms/step - loss: 0.1815 - accuracy: 0.9335 - val_loss: 0.1663 - val_accuracy: 0.9413
# Epoch 80/140
# 93/93 [==============================] - 1s 12ms/step - loss: 0.1786 - accuracy: 0.9332 - val_loss: 0.1637 - val_accuracy: 0.9413
# Epoch 81/140
# 93/93 [==============================] - 1s 10ms/step - loss: 0.1788 - accuracy: 0.9336 - val_loss: 0.1629 - val_accuracy: 0.9404
# Epoch 82/140
# 93/93 [==============================] - 1s 11ms/step - loss: 0.1780 - accuracy: 0.9337 - val_loss: 0.1607 - val_accuracy: 0.9417
# Epoch 83/140
# 93/93 [==============================] - 1s 11ms/step - loss: 0.1783 - accuracy: 0.9333 - val_loss: 0.1650 - val_accuracy: 0.9415
# Epoch 84/140
# 93/93 [==============================] - 1s 10ms/step - loss: 0.1756 - accuracy: 0.9356 - val_loss: 0.1602 - val_accuracy: 0.9420
# Epoch 85/140
# 93/93 [==============================] - 1s 11ms/step - loss: 0.1777 - accuracy: 0.9336 - val_loss: 0.1637 - val_accuracy: 0.9420
# Epoch 86/140
# 93/93 [==============================] - 1s 11ms/step - loss: 0.1788 - accuracy: 0.9342 - val_loss: 0.1605 - val_accuracy: 0.9420
# Epoch 87/140
# 93/93 [==============================] - 1s 10ms/step - loss: 0.1737 - accuracy: 0.9364 - val_loss: 0.1579 - val_accuracy: 0.9428
# Epoch 88/140
# 93/93 [==============================] - 1s 10ms/step - loss: 0.1731 - accuracy: 0.9363 - val_loss: 0.1612 - val_accuracy: 0.9430
# Epoch 89/140
# 93/93 [==============================] - 1s 11ms/step - loss: 0.1775 - accuracy: 0.9358 - val_loss: 0.1607 - val_accuracy: 0.9426
# Epoch 90/140
# 93/93 [==============================] - 1s 11ms/step - loss: 0.1759 - accuracy: 0.9354 - val_loss: 0.1611 - val_accuracy: 0.9422
# Epoch 91/140
# 93/93 [==============================] - 1s 12ms/step - loss: 0.1732 - accuracy: 0.9365 - val_loss: 0.1580 - val_accuracy: 0.9426
# Epoch 92/140
# 93/93 [==============================] - 1s 11ms/step - loss: 0.1722 - accuracy: 0.9366 - val_loss: 0.1564 - val_accuracy: 0.9426
# Epoch 93/140
# 93/93 [==============================] - 1s 10ms/step - loss: 0.1697 - accuracy: 0.9373 - val_loss: 0.1586 - val_accuracy: 0.9426
# Epoch 94/140
# 93/93 [==============================] - 1s 10ms/step - loss: 0.1764 - accuracy: 0.9347 - val_loss: 0.1556 - val_accuracy: 0.9432
# Epoch 95/140
# 93/93 [==============================] - 1s 11ms/step - loss: 0.1711 - accuracy: 0.9375 - val_loss: 0.1558 - val_accuracy: 0.9426
# Epoch 96/140
# 93/93 [==============================] - 1s 11ms/step - loss: 0.1677 - accuracy: 0.9374 - val_loss: 0.1537 - val_accuracy: 0.9428
# Epoch 97/140
# 93/93 [==============================] - 1s 12ms/step - loss: 0.1747 - accuracy: 0.9351 - val_loss: 0.1550 - val_accuracy: 0.9432
# Epoch 98/140
# 93/93 [==============================] - 1s 11ms/step - loss: 0.1654 - accuracy: 0.9418 - val_loss: 0.1540 - val_accuracy: 0.9437
# Epoch 99/140
# 93/93 [==============================] - 1s 11ms/step - loss: 0.1695 - accuracy: 0.9378 - val_loss: 0.1552 - val_accuracy: 0.9437
# Epoch 100/140
# 93/93 [==============================] - 1s 12ms/step - loss: 0.1668 - accuracy: 0.9384 - val_loss: 0.1529 - val_accuracy: 0.9430
# Epoch 101/140
# 93/93 [==============================] - 1s 13ms/step - loss: 0.1688 - accuracy: 0.9371 - val_loss: 0.1524 - val_accuracy: 0.9435
# Epoch 102/140
# 93/93 [==============================] - 1s 13ms/step - loss: 0.1678 - accuracy: 0.9384 - val_loss: 0.1548 - val_accuracy: 0.9430
# Epoch 103/140
# 93/93 [==============================] - 2s 16ms/step - loss: 0.1681 - accuracy: 0.9376 - val_loss: 0.1552 - val_accuracy: 0.9439
# Epoch 104/140
# 93/93 [==============================] - 2s 18ms/step - loss: 0.1705 - accuracy: 0.9370 - val_loss: 0.1521 - val_accuracy: 0.9430
# Epoch 105/140
# 93/93 [==============================] - 1s 16ms/step - loss: 0.1689 - accuracy: 0.9361 - val_loss: 0.1528 - val_accuracy: 0.9441
# Epoch 106/140
# 93/93 [==============================] - 1s 15ms/step - loss: 0.1690 - accuracy: 0.9384 - val_loss: 0.1532 - val_accuracy: 0.9439
# Epoch 107/140
# 93/93 [==============================] - 1s 16ms/step - loss: 0.1684 - accuracy: 0.9371 - val_loss: 0.1509 - val_accuracy: 0.9437
# Epoch 108/140
# 93/93 [==============================] - 1s 13ms/step - loss: 0.1679 - accuracy: 0.9383 - val_loss: 0.1513 - val_accuracy: 0.9439
# Epoch 109/140
# 93/93 [==============================] - 1s 12ms/step - loss: 0.1664 - accuracy: 0.9389 - val_loss: 0.1525 - val_accuracy: 0.9437
# Epoch 110/140
# 93/93 [==============================] - 1s 13ms/step - loss: 0.1629 - accuracy: 0.9405 - val_loss: 0.1535 - val_accuracy: 0.9443
# Epoch 111/140
# 93/93 [==============================] - 1s 14ms/step - loss: 0.1666 - accuracy: 0.9391 - val_loss: 0.1511 - val_accuracy: 0.9432
# Epoch 112/140
# 93/93 [==============================] - 1s 14ms/step - loss: 0.1640 - accuracy: 0.9396 - val_loss: 0.1519 - val_accuracy: 0.9439
# Epoch 113/140
# 93/93 [==============================] - 1s 13ms/step - loss: 0.1646 - accuracy: 0.9398 - val_loss: 0.1512 - val_accuracy: 0.9441
# Epoch 114/140
# 93/93 [==============================] - 1s 14ms/step - loss: 0.1623 - accuracy: 0.9401 - val_loss: 0.1475 - val_accuracy: 0.9437
# Epoch 115/140
# 93/93 [==============================] - 1s 15ms/step - loss: 0.1634 - accuracy: 0.9403 - val_loss: 0.1487 - val_accuracy: 0.9443
# Epoch 116/140
# 93/93 [==============================] - 1s 13ms/step - loss: 0.1603 - accuracy: 0.9406 - val_loss: 0.1492 - val_accuracy: 0.9443
# Epoch 117/140
# 93/93 [==============================] - 1s 13ms/step - loss: 0.1622 - accuracy: 0.9410 - val_loss: 0.1488 - val_accuracy: 0.9452
# Epoch 118/140
# 93/93 [==============================] - 1s 13ms/step - loss: 0.1645 - accuracy: 0.9392 - val_loss: 0.1506 - val_accuracy: 0.9441
# Epoch 119/140
# 93/93 [==============================] - 1s 13ms/step - loss: 0.1611 - accuracy: 0.9424 - val_loss: 0.1484 - val_accuracy: 0.9448
# Epoch 120/140
# 93/93 [==============================] - 1s 12ms/step - loss: 0.1611 - accuracy: 0.9395 - val_loss: 0.1464 - val_accuracy: 0.9448
# Epoch 121/140
# 93/93 [==============================] - 1s 13ms/step - loss: 0.1628 - accuracy: 0.9404 - val_loss: 0.1492 - val_accuracy: 0.9450
# Epoch 122/140
# 93/93 [==============================] - 1s 13ms/step - loss: 0.1626 - accuracy: 0.9389 - val_loss: 0.1485 - val_accuracy: 0.9454
# Epoch 123/140
# 93/93 [==============================] - 1s 13ms/step - loss: 0.1657 - accuracy: 0.9395 - val_loss: 0.1472 - val_accuracy: 0.9452
# Epoch 124/140
# 93/93 [==============================] - 1s 12ms/step - loss: 0.1594 - accuracy: 0.9413 - val_loss: 0.1456 - val_accuracy: 0.9450
# Epoch 125/140
# 93/93 [==============================] - 1s 13ms/step - loss: 0.1617 - accuracy: 0.9399 - val_loss: 0.1501 - val_accuracy: 0.9428
# Epoch 126/140
# 93/93 [==============================] - 1s 12ms/step - loss: 0.1640 - accuracy: 0.9398 - val_loss: 0.1475 - val_accuracy: 0.9450
# Epoch 127/140
# 93/93 [==============================] - 1s 12ms/step - loss: 0.1601 - accuracy: 0.9411 - val_loss: 0.1462 - val_accuracy: 0.9452
# Epoch 128/140
# 93/93 [==============================] - 1s 13ms/step - loss: 0.1579 - accuracy: 0.9424 - val_loss: 0.1471 - val_accuracy: 0.9456
# Epoch 129/140
# 93/93 [==============================] - 1s 13ms/step - loss: 0.1600 - accuracy: 0.9406 - val_loss: 0.1455 - val_accuracy: 0.9454
# Epoch 130/140
# 93/93 [==============================] - 1s 13ms/step - loss: 0.1588 - accuracy: 0.9428 - val_loss: 0.1457 - val_accuracy: 0.9458
# Epoch 131/140
# 93/93 [==============================] - 1s 13ms/step - loss: 0.1543 - accuracy: 0.9435 - val_loss: 0.1444 - val_accuracy: 0.9454
# Epoch 132/140
# 93/93 [==============================] - 1s 12ms/step - loss: 0.1563 - accuracy: 0.9421 - val_loss: 0.1429 - val_accuracy: 0.9458
# Epoch 133/140
# 93/93 [==============================] - 1s 13ms/step - loss: 0.1568 - accuracy: 0.9423 - val_loss: 0.1461 - val_accuracy: 0.9448
# Epoch 134/140
# 93/93 [==============================] - 1s 14ms/step - loss: 0.1572 - accuracy: 0.9410 - val_loss: 0.1441 - val_accuracy: 0.9454
# Epoch 135/140
# 93/93 [==============================] - 1s 12ms/step - loss: 0.1555 - accuracy: 0.9435 - val_loss: 0.1413 - val_accuracy: 0.9465
# Epoch 136/140
# 93/93 [==============================] - 1s 11ms/step - loss: 0.1562 - accuracy: 0.9411 - val_loss: 0.1486 - val_accuracy: 0.9432
# Epoch 137/140
# 93/93 [==============================] - 1s 12ms/step - loss: 0.1595 - accuracy: 0.9421 - val_loss: 0.1429 - val_accuracy: 0.9456
# Epoch 138/140
# 93/93 [==============================] - 1s 13ms/step - loss: 0.1542 - accuracy: 0.9425 - val_loss: 0.1457 - val_accuracy: 0.9454
# Epoch 139/140
# 93/93 [==============================] - 1s 15ms/step - loss: 0.1527 - accuracy: 0.9438 - val_loss: 0.1448 - val_accuracy: 0.9454
# Epoch 140/140
# 93/93 [==============================] - 1s 12ms/step - loss: 0.1547 - accuracy: 0.9418 - val_loss: 0.1429 - val_accuracy: 0.9458
# 145/145 [==============================] - 0s 2ms/step
# voici le seuil médiand 0.3546139
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.94      0.95      2789
#          1.0       0.91      0.95      0.93      1845
#
#     accuracy                           0.94      4634
#    macro avg       0.94      0.94      0.94      4634
# weighted avg       0.94      0.94      0.94      4634

# %%
plt.hist(neuronal_network.predict(X_test),100,color='g',density=False,label='proba de test')
plt.grid()
plt.legend()
plt.title("Histogram sur les données test")
plt.show()


plt.hist(neuronal_network.predict(df_test_std),100,density=False,label='proba de validation')
plt.grid()
plt.legend()
plt.show()
# Out:
#   1/145 [..............................] - ETA: 3s145/145 [==============================] - 0s 2ms/step
# 30/30 [==============================] - 0s 2ms/step

# %%
df_soumission3 = df_test.drop(df_test.columns,axis = 1)
df_soumission3['pos_label'] = neuronal_network.predict(df_test_std)
df_soumission3.to_csv("/home/ibotcazou/Bureau/Master_data_science/DATAS_M2/Apprentissage_Statistique_Panloup/Data_challenge/soumission3_neuronal1.csv")
# Out:
# 30/30 [==============================] - 0s 2ms/step

# %% [markdown]
# # Second neuronal network

# %%
neuronal_network = Sequential()
neuronal_network.add(Dense(686,input_dim=X_train.shape[1], activation='relu'))  
# input_shape doit correspondre à la forme de vos données d'entrée
neuronal_network.add(Dropout(0.5))

neuronal_network.add(Dense(228, activation='relu'))  
neuronal_network.add(Dropout(0.5))

neuronal_network.add(Dense(76, activation='relu'))  
neuronal_network.add(Dropout(0.5))

neuronal_network.add(Dense(25, activation='relu'))  
neuronal_network.add(Dropout(0.5))

neuronal_network.add(Dense(1, activation='sigmoid'))  # Sortie binaire

evaluation_model(neuronal_network,X_train,X_test,Y_train,Y_test, batch_size=80, epochs=100,lr=0.0001)
#batch_size est le nombre d'individus utilisés pour la descente de gradient lors du Mini Bach
# 1 epoch est égale à N/batch_sige  fois ou on fait tourner l'algo
# Out:
# Epoch 1/100
# 232/232 [==============================] - 2s 7ms/step - loss: 0.6877 - accuracy: 0.6000 - val_loss: 0.5859 - val_accuracy: 0.8205
# Epoch 2/100
# 232/232 [==============================] - 1s 6ms/step - loss: 0.5595 - accuracy: 0.7236 - val_loss: 0.4049 - val_accuracy: 0.8608
# Epoch 3/100
# 232/232 [==============================] - 1s 6ms/step - loss: 0.4449 - accuracy: 0.8106 - val_loss: 0.3061 - val_accuracy: 0.8874
# Epoch 4/100
# 232/232 [==============================] - 1s 6ms/step - loss: 0.3721 - accuracy: 0.8541 - val_loss: 0.2613 - val_accuracy: 0.9059
# Epoch 5/100
# 232/232 [==============================] - 1s 6ms/step - loss: 0.3340 - accuracy: 0.8767 - val_loss: 0.2431 - val_accuracy: 0.9130
# Epoch 6/100
# 232/232 [==============================] - 2s 7ms/step - loss: 0.2977 - accuracy: 0.8912 - val_loss: 0.2251 - val_accuracy: 0.9171
# Epoch 7/100
# 232/232 [==============================] - 1s 6ms/step - loss: 0.2877 - accuracy: 0.9017 - val_loss: 0.2098 - val_accuracy: 0.9243
# Epoch 8/100
# 232/232 [==============================] - 2s 7ms/step - loss: 0.2755 - accuracy: 0.9067 - val_loss: 0.2017 - val_accuracy: 0.9273
# Epoch 9/100
# 232/232 [==============================] - 1s 6ms/step - loss: 0.2565 - accuracy: 0.9151 - val_loss: 0.1947 - val_accuracy: 0.9312
# Epoch 10/100
# 232/232 [==============================] - 1s 6ms/step - loss: 0.2434 - accuracy: 0.9178 - val_loss: 0.1841 - val_accuracy: 0.9335
# Epoch 11/100
# 232/232 [==============================] - 1s 6ms/step - loss: 0.2318 - accuracy: 0.9239 - val_loss: 0.1780 - val_accuracy: 0.9353
# Epoch 12/100
# 232/232 [==============================] - 1s 6ms/step - loss: 0.2209 - accuracy: 0.9247 - val_loss: 0.1749 - val_accuracy: 0.9363
# Epoch 13/100
# 232/232 [==============================] - 1s 6ms/step - loss: 0.2168 - accuracy: 0.9271 - val_loss: 0.1653 - val_accuracy: 0.9374
# Epoch 14/100
# 232/232 [==============================] - 1s 6ms/step - loss: 0.2084 - accuracy: 0.9320 - val_loss: 0.1627 - val_accuracy: 0.9374
# Epoch 15/100
# 232/232 [==============================] - 1s 6ms/step - loss: 0.2018 - accuracy: 0.9327 - val_loss: 0.1557 - val_accuracy: 0.9409
# Epoch 16/100
# 232/232 [==============================] - 1s 6ms/step - loss: 0.1971 - accuracy: 0.9323 - val_loss: 0.1519 - val_accuracy: 0.9417
# Epoch 17/100
# 232/232 [==============================] - 1s 6ms/step - loss: 0.1901 - accuracy: 0.9360 - val_loss: 0.1492 - val_accuracy: 0.9441
# Epoch 18/100
# 232/232 [==============================] - 1s 6ms/step - loss: 0.1896 - accuracy: 0.9369 - val_loss: 0.1449 - val_accuracy: 0.9452
# Epoch 19/100
# 232/232 [==============================] - 2s 6ms/step - loss: 0.1790 - accuracy: 0.9416 - val_loss: 0.1411 - val_accuracy: 0.9463
# Epoch 20/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.1764 - accuracy: 0.9398 - val_loss: 0.1402 - val_accuracy: 0.9465
# Epoch 21/100
# 232/232 [==============================] - 1s 6ms/step - loss: 0.1685 - accuracy: 0.9444 - val_loss: 0.1326 - val_accuracy: 0.9471
# Epoch 22/100
# 232/232 [==============================] - 1s 6ms/step - loss: 0.1664 - accuracy: 0.9435 - val_loss: 0.1306 - val_accuracy: 0.9504
# Epoch 23/100
# 232/232 [==============================] - 1s 6ms/step - loss: 0.1607 - accuracy: 0.9437 - val_loss: 0.1363 - val_accuracy: 0.9478
# Epoch 24/100
# 232/232 [==============================] - 2s 7ms/step - loss: 0.1596 - accuracy: 0.9455 - val_loss: 0.1264 - val_accuracy: 0.9534
# Epoch 25/100
# 232/232 [==============================] - 2s 7ms/step - loss: 0.1552 - accuracy: 0.9456 - val_loss: 0.1222 - val_accuracy: 0.9510
# Epoch 26/100
# 232/232 [==============================] - 2s 7ms/step - loss: 0.1504 - accuracy: 0.9483 - val_loss: 0.1219 - val_accuracy: 0.9534
# Epoch 27/100
# 232/232 [==============================] - 2s 7ms/step - loss: 0.1481 - accuracy: 0.9500 - val_loss: 0.1176 - val_accuracy: 0.9560
# Epoch 28/100
# 232/232 [==============================] - 1s 6ms/step - loss: 0.1475 - accuracy: 0.9479 - val_loss: 0.1167 - val_accuracy: 0.9543
# Epoch 29/100
# 232/232 [==============================] - 2s 7ms/step - loss: 0.1436 - accuracy: 0.9500 - val_loss: 0.1132 - val_accuracy: 0.9566
# Epoch 30/100
# 232/232 [==============================] - 2s 7ms/step - loss: 0.1397 - accuracy: 0.9521 - val_loss: 0.1126 - val_accuracy: 0.9575
# Epoch 31/100
# 232/232 [==============================] - 1s 6ms/step - loss: 0.1386 - accuracy: 0.9521 - val_loss: 0.1098 - val_accuracy: 0.9579
# Epoch 32/100
# 232/232 [==============================] - 1s 6ms/step - loss: 0.1357 - accuracy: 0.9535 - val_loss: 0.1102 - val_accuracy: 0.9575
# Epoch 33/100
# 232/232 [==============================] - 1s 6ms/step - loss: 0.1399 - accuracy: 0.9535 - val_loss: 0.1107 - val_accuracy: 0.9579
# Epoch 34/100
# 232/232 [==============================] - 2s 7ms/step - loss: 0.1336 - accuracy: 0.9521 - val_loss: 0.1107 - val_accuracy: 0.9571
# Epoch 35/100
# 232/232 [==============================] - 2s 7ms/step - loss: 0.1329 - accuracy: 0.9534 - val_loss: 0.1105 - val_accuracy: 0.9581
# Epoch 36/100
# 232/232 [==============================] - 1s 6ms/step - loss: 0.1302 - accuracy: 0.9561 - val_loss: 0.1065 - val_accuracy: 0.9607
# Epoch 37/100
# 232/232 [==============================] - 1s 6ms/step - loss: 0.1237 - accuracy: 0.9567 - val_loss: 0.1073 - val_accuracy: 0.9609
# Epoch 38/100
# 232/232 [==============================] - 2s 7ms/step - loss: 0.1240 - accuracy: 0.9545 - val_loss: 0.1088 - val_accuracy: 0.9599
# Epoch 39/100
# 232/232 [==============================] - 1s 6ms/step - loss: 0.1197 - accuracy: 0.9595 - val_loss: 0.1013 - val_accuracy: 0.9616
# Epoch 40/100
# 232/232 [==============================] - 1s 6ms/step - loss: 0.1219 - accuracy: 0.9571 - val_loss: 0.1035 - val_accuracy: 0.9614
# Epoch 41/100
# 232/232 [==============================] - 2s 7ms/step - loss: 0.1214 - accuracy: 0.9580 - val_loss: 0.1062 - val_accuracy: 0.9599
# Epoch 42/100
# 232/232 [==============================] - 2s 7ms/step - loss: 0.1212 - accuracy: 0.9567 - val_loss: 0.1074 - val_accuracy: 0.9590
# Epoch 43/100
# 232/232 [==============================] - 2s 7ms/step - loss: 0.1183 - accuracy: 0.9576 - val_loss: 0.0989 - val_accuracy: 0.9629
# Epoch 44/100
# 232/232 [==============================] - 1s 6ms/step - loss: 0.1159 - accuracy: 0.9596 - val_loss: 0.0979 - val_accuracy: 0.9640
# Epoch 45/100
# 232/232 [==============================] - 1s 6ms/step - loss: 0.1162 - accuracy: 0.9601 - val_loss: 0.0973 - val_accuracy: 0.9648
# Epoch 46/100
# 232/232 [==============================] - 1s 6ms/step - loss: 0.1149 - accuracy: 0.9603 - val_loss: 0.0972 - val_accuracy: 0.9637
# Epoch 47/100
# 232/232 [==============================] - 2s 7ms/step - loss: 0.1101 - accuracy: 0.9611 - val_loss: 0.0967 - val_accuracy: 0.9635
# Epoch 48/100
# 232/232 [==============================] - 2s 7ms/step - loss: 0.1110 - accuracy: 0.9615 - val_loss: 0.0940 - val_accuracy: 0.9657
# Epoch 49/100
# 232/232 [==============================] - 1s 6ms/step - loss: 0.1147 - accuracy: 0.9609 - val_loss: 0.0958 - val_accuracy: 0.9661
# Epoch 50/100
# 232/232 [==============================] - 1s 6ms/step - loss: 0.1121 - accuracy: 0.9601 - val_loss: 0.0938 - val_accuracy: 0.9640
# Epoch 51/100
# 232/232 [==============================] - 1s 6ms/step - loss: 0.1075 - accuracy: 0.9615 - val_loss: 0.0911 - val_accuracy: 0.9650
# Epoch 52/100
# 232/232 [==============================] - 2s 7ms/step - loss: 0.1057 - accuracy: 0.9628 - val_loss: 0.0933 - val_accuracy: 0.9644
# Epoch 53/100
# 232/232 [==============================] - 2s 6ms/step - loss: 0.1032 - accuracy: 0.9640 - val_loss: 0.0916 - val_accuracy: 0.9648
# Epoch 54/100
# 232/232 [==============================] - 1s 6ms/step - loss: 0.1035 - accuracy: 0.9643 - val_loss: 0.0920 - val_accuracy: 0.9661
# Epoch 55/100
# 232/232 [==============================] - 1s 6ms/step - loss: 0.1019 - accuracy: 0.9640 - val_loss: 0.0901 - val_accuracy: 0.9676
# Epoch 56/100
# 232/232 [==============================] - 2s 7ms/step - loss: 0.1011 - accuracy: 0.9644 - val_loss: 0.0907 - val_accuracy: 0.9648
# Epoch 57/100
# 232/232 [==============================] - 1s 6ms/step - loss: 0.1018 - accuracy: 0.9631 - val_loss: 0.0924 - val_accuracy: 0.9655
# Epoch 58/100
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0989 - accuracy: 0.9664 - val_loss: 0.0886 - val_accuracy: 0.9676
# Epoch 59/100
# 232/232 [==============================] - 1s 6ms/step - loss: 0.0978 - accuracy: 0.9657 - val_loss: 0.0894 - val_accuracy: 0.9659
# Epoch 60/100
# 232/232 [==============================] - 2s 7ms/step - loss: 0.1009 - accuracy: 0.9640 - val_loss: 0.0911 - val_accuracy: 0.9655
# Epoch 61/100
# 232/232 [==============================] - 2s 6ms/step - loss: 0.0958 - accuracy: 0.9654 - val_loss: 0.0876 - val_accuracy: 0.9663
# Epoch 62/100
# 232/232 [==============================] - 1s 6ms/step - loss: 0.0982 - accuracy: 0.9642 - val_loss: 0.0892 - val_accuracy: 0.9659
# Epoch 63/100
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0904 - accuracy: 0.9671 - val_loss: 0.0889 - val_accuracy: 0.9666
# Epoch 64/100
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0930 - accuracy: 0.9662 - val_loss: 0.1001 - val_accuracy: 0.9625
# Epoch 65/100
# 232/232 [==============================] - 1s 6ms/step - loss: 0.0958 - accuracy: 0.9662 - val_loss: 0.0849 - val_accuracy: 0.9678
# Epoch 66/100
# 232/232 [==============================] - 1s 6ms/step - loss: 0.0929 - accuracy: 0.9659 - val_loss: 0.0837 - val_accuracy: 0.9685
# Epoch 67/100
# 232/232 [==============================] - 1s 6ms/step - loss: 0.0916 - accuracy: 0.9662 - val_loss: 0.0852 - val_accuracy: 0.9676
# Epoch 68/100
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0900 - accuracy: 0.9677 - val_loss: 0.0882 - val_accuracy: 0.9681
# Epoch 69/100
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0870 - accuracy: 0.9675 - val_loss: 0.0880 - val_accuracy: 0.9670
# Epoch 70/100
# 232/232 [==============================] - 1s 6ms/step - loss: 0.0897 - accuracy: 0.9693 - val_loss: 0.0828 - val_accuracy: 0.9683
# Epoch 71/100
# 232/232 [==============================] - 1s 6ms/step - loss: 0.0907 - accuracy: 0.9680 - val_loss: 0.0802 - val_accuracy: 0.9707
# Epoch 72/100
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0894 - accuracy: 0.9676 - val_loss: 0.0852 - val_accuracy: 0.9691
# Epoch 73/100
# 232/232 [==============================] - 1s 6ms/step - loss: 0.0869 - accuracy: 0.9692 - val_loss: 0.0834 - val_accuracy: 0.9685
# Epoch 74/100
# 232/232 [==============================] - 1s 6ms/step - loss: 0.0894 - accuracy: 0.9681 - val_loss: 0.0842 - val_accuracy: 0.9687
# Epoch 75/100
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0876 - accuracy: 0.9681 - val_loss: 0.0842 - val_accuracy: 0.9689
# Epoch 76/100
# 232/232 [==============================] - 2s 6ms/step - loss: 0.0860 - accuracy: 0.9672 - val_loss: 0.0816 - val_accuracy: 0.9691
# Epoch 77/100
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0837 - accuracy: 0.9698 - val_loss: 0.0831 - val_accuracy: 0.9683
# Epoch 78/100
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0854 - accuracy: 0.9696 - val_loss: 0.0829 - val_accuracy: 0.9678
# Epoch 79/100
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0838 - accuracy: 0.9692 - val_loss: 0.0822 - val_accuracy: 0.9696
# Epoch 80/100
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0826 - accuracy: 0.9701 - val_loss: 0.0806 - val_accuracy: 0.9698
# Epoch 81/100
# 232/232 [==============================] - 1s 6ms/step - loss: 0.0841 - accuracy: 0.9687 - val_loss: 0.0809 - val_accuracy: 0.9689
# Epoch 81: early stopping
# 145/145 [==============================] - 0s 2ms/step
# voici le seuil médiand 0.68798053
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.98      0.97      2789
#          1.0       0.97      0.94      0.96      1845
#
#     accuracy                           0.97      4634
#    macro avg       0.97      0.96      0.96      4634
# weighted avg       0.97      0.97      0.97      4634

# %%
plt.hist(neuronal_network.predict(X_test),100,color='g',density=False,label='proba de test')
plt.grid()
plt.legend()
plt.title("Histogram sur les données test")
plt.show()


plt.hist(neuronal_network.predict(df_test_std),100,density=False,label='proba de validation')
plt.grid()
plt.legend()
plt.show()
# Out:
# 145/145 [==============================] - 0s 2ms/step
# 30/30 [==============================] - 0s 2ms/step

# %%
df_soumission4 = df_test.drop(df_test.columns,axis = 1)
df_soumission4['pos_label'] = neuronal_network.predict(df_test_std)
df_soumission4.to_csv("/home/ibotcazou/Bureau/Master_data_science/DATAS_M2/Apprentissage_Statistique_Panloup/Data_challenge/soumission4_neuronal1.csv")
# Out:
# 30/30 [==============================] - 0s 3ms/step

# %% [markdown]
# ## Neuronal network session 3 avec plus de features et passage au log

# %% [markdown]
# ### Chargement des données avec plus de features et passage au log2

# %%
df = pd.read_csv("/home/ibotcazou/Bureau/Master_data_science/DATAS_M2/Apprentissage_Statistique_Panloup/Data_challenge/features776_data.csv",index_col=0)
df.index = range(1,len(df)+1)
df_log_std = df.copy()

df_test = pd.read_csv("/home/ibotcazou/Bureau/Master_data_science/DATAS_M2/Apprentissage_Statistique_Panloup/Data_challenge/test_features776_data.csv",index_col='id')
df_test = df_test.iloc[:,1:]
df_test_log_std = df_test.copy()

##Passage au log2 sur les amplitudes de fréquences 
eps = 1e-10
df_log_std.iloc[:,1:len(frequences)+1] = np.log(df_log_std.iloc[:,1:len(frequences)+1]+eps)/np.log(2)
df_test_log_std.iloc[:,0:len(frequences)] = np.log(df_test_log_std.iloc[:,0:len(frequences)]+eps)/np.log(2)

#Standardisation des données
df_log_std.iloc[:,1:] = (df_log_std.iloc[:,1:] - df_log_std.iloc[:,1:].mean(axis=0))/df_log_std.iloc[:,1:].std(axis=0)
df_test_log_std = (df_test_log_std - df_test_log_std.mean(axis=0) )/ df_test_log_std.std(axis=0)

trainset, testset = train_test_split(df_log_std, test_size=0.3,random_state=0)

def preprocessing(dataframe):
    return dataframe.drop('target',axis=1), dataframe.target

X_train,Y_train = preprocessing(trainset)
X_test,Y_test = preprocessing(testset)

# %%
neuronal_network = Sequential()
neuronal_network.add(Dense(686,input_dim=X_train.shape[1], activation='relu'))  # input_shape doit correspondre à la forme de vos données d'entrée
neuronal_network.add(Dropout(0.5))

neuronal_network.add(Dense(228, activation='relu'))  # input_shape doit correspondre à la forme de vos données d'entrée
neuronal_network.add(Dropout(0.5))

neuronal_network.add(Dense(76, activation='relu'))  # input_shape doit correspondre à la forme de vos données d'entrée
neuronal_network.add(Dropout(0.5))

neuronal_network.add(Dense(25, activation='relu'))  # input_shape doit correspondre à la forme de vos données d'entrée
neuronal_network.add(Dropout(0.5))

neuronal_network.add(Dense(1, activation='sigmoid'))  # Sortie binaire

# %%
tf.keras.utils.plot_model(
    neuronal_network,
    to_file='/home/ibotcazou/Bureau/Master_data_science/DATAS_M2/Apprentissage_Statistique_Panloup/Data_challenge/model1.png',
    show_shapes=False,
    show_dtype=False,
    show_layer_names=True,
    rankdir='TB',
    expand_nested=False,
    dpi=96,
    layer_range=None,
    show_layer_activations=False,
    show_trainable=False
)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %%
evaluation_model(neuronal_network,X_train,X_test,Y_train,Y_test, batch_size=80, epochs=40,lr=0.0001)
#batch_size est le nombre d'individus utilisés pour la descente de gradient lors du Mini Bach
# 1 epoch est égale à N/batch_sige  fois ou on fait tourner l'algo 
evaluation_model(neuronal_network,X_train,X_test,Y_train,Y_test, batch_size=80, epochs=40,lr=0.00003)
#batch_size est le nombre d'individus utilisés pour la descente de gradient lors du Mini Bach
# 1 epoch est égale à N/batch_sige  fois ou on fait tourner l'algo

# %%
plt.hist(neuronal_network.predict(X_test),100,color='g',density=False,label='proba de test')
plt.grid()
plt.legend()
plt.title("Histogram sur les données test")
plt.show()


plt.hist(neuronal_network.predict(df_test_log_std),100,density=False,label='proba de validation')
plt.grid()
plt.legend()
plt.show()
# Out:
#   1/218 [..............................] - ETA: 8s218/218 [==============================] - 1s 3ms/step
# 30/30 [==============================] - 0s 2ms/step

# %%
df_soumission5 = df_test_log_std.drop(df_test.columns,axis = 1)
df_soumission5['pos_label'] = neuronal_network.predict(df_test_log_std)
df_soumission5.to_csv("/home/ibotcazou/Bureau/Master_data_science/DATAS_M2/Apprentissage_Statistique_Panloup/Data_challenge/soumission5_neuronal1.csv") ## Score : 0,9025902305198276
# Out:
# 30/30 [==============================] - 0s 3ms/step

# %% [markdown]
# ## Neuronal network session 4 avec plus de features et passage au log

# %%
df = pd.read_csv("/home/ibotcazou/Bureau/Master_data_science/DATAS_M2/Apprentissage_Statistique_Panloup/Data_challenge/features950_data.csv",index_col=0)
df.index = df.id
df = df.drop(columns='id',axis=1)
df_log_std = df.copy()

df_test = pd.read_csv("/home/ibotcazou/Bureau/Master_data_science/DATAS_M2/Apprentissage_Statistique_Panloup/Data_challenge/test_features950_data.csv",index_col='id')
df_test = df_test.iloc[:,1:]
df_test_log_std = df_test.copy()

##Passage au log2 sur les amplitudes de fréquences 
eps = 1e-6
df_log_std.iloc[:,1:len(frequences)+1] = np.log(df_log_std.iloc[:,1:len(frequences)+1]+eps)/np.log(2)
df_test_log_std.iloc[:,0:len(frequences)] = np.log(df_test_log_std.iloc[:,0:len(frequences)]+eps)/np.log(2)

#Standardisation des données
df_log_std.iloc[:,1:] = (df_log_std.iloc[:,1:] - df_log_std.iloc[:,1:].mean(axis=0))/df_log_std.iloc[:,1:].std(axis=0)
df_test_log_std = (df_test_log_std - df_test_log_std.mean(axis=0) )/ df_test_log_std.std(axis=0)

trainset, testset = train_test_split(df_log_std, test_size=0.3,random_state=0)

def preprocessing(dataframe):
    return dataframe.drop('target',axis=1), dataframe.target

X_train,Y_train = preprocessing(trainset)
X_test,Y_test = preprocessing(testset)

# %%
neuronal_network = Sequential()
neuronal_network.add(Dense(700,input_dim=X_train.shape[1], activation='relu'))  # input_shape doit correspondre à la forme de vos données d'entrée
neuronal_network.add(Dropout(0.5))

neuronal_network.add(Dense(500, activation='relu'))  # input_shape doit correspondre à la forme de vos données d'entrée
neuronal_network.add(Dropout(0.5))

neuronal_network.add(Dense(150, activation='relu'))  # input_shape doit correspondre à la forme de vos données d'entrée
neuronal_network.add(Dropout(0.5))

neuronal_network.add(Dense(80, activation='relu'))  # input_shape doit correspondre à la forme de vos données d'entrée
neuronal_network.add(Dropout(0.5))

neuronal_network.add(Dense(1, activation='sigmoid'))  # Sortie binaire

evaluation_model(neuronal_network,X_train,X_test,Y_train,Y_test, batch_size=100, epochs=40,lr=0.0001)
#batch_size est le nombre d'individus utilisés pour la descente de gradient lors du Mini Bach
# 1 epoch est égale à N/batch_sige  fois ou on fait tourner l'algo
# Out:
# Epoch 1/40
# 163/163 [==============================] - 4s 19ms/step - loss: 0.7462 - accuracy: 0.5710 - val_loss: 0.5725 - val_accuracy: 0.7705
# Epoch 2/40
# 163/163 [==============================] - 3s 18ms/step - loss: 0.5874 - accuracy: 0.6817 - val_loss: 0.4546 - val_accuracy: 0.8249
# Epoch 3/40
# 163/163 [==============================] - 3s 18ms/step - loss: 0.4715 - accuracy: 0.7866 - val_loss: 0.3376 - val_accuracy: 0.8748
# Epoch 4/40
# 163/163 [==============================] - 3s 17ms/step - loss: 0.3801 - accuracy: 0.8434 - val_loss: 0.2641 - val_accuracy: 0.9042
# Epoch 5/40
# 163/163 [==============================] - 3s 17ms/step - loss: 0.3171 - accuracy: 0.8771 - val_loss: 0.2186 - val_accuracy: 0.9217
# Epoch 6/40
# 163/163 [==============================] - 3s 17ms/step - loss: 0.2834 - accuracy: 0.8957 - val_loss: 0.2138 - val_accuracy: 0.9164
# Epoch 7/40
# 163/163 [==============================] - 3s 18ms/step - loss: 0.2601 - accuracy: 0.9049 - val_loss: 0.1918 - val_accuracy: 0.9222
# Epoch 8/40
# 163/163 [==============================] - 3s 18ms/step - loss: 0.2468 - accuracy: 0.9106 - val_loss: 0.2123 - val_accuracy: 0.9219
# Epoch 9/40
# 163/163 [==============================] - 3s 18ms/step - loss: 0.2335 - accuracy: 0.9148 - val_loss: 0.1747 - val_accuracy: 0.9324
# Epoch 10/40
# 163/163 [==============================] - 3s 18ms/step - loss: 0.2271 - accuracy: 0.9166 - val_loss: 0.1617 - val_accuracy: 0.9409
# Epoch 11/40
# 163/163 [==============================] - 3s 17ms/step - loss: 0.2029 - accuracy: 0.9244 - val_loss: 0.1718 - val_accuracy: 0.9371
# Epoch 12/40
# 163/163 [==============================] - 3s 18ms/step - loss: 0.1997 - accuracy: 0.9276 - val_loss: 0.1506 - val_accuracy: 0.9436
# Epoch 13/40
# 163/163 [==============================] - 3s 18ms/step - loss: 0.1820 - accuracy: 0.9330 - val_loss: 0.1560 - val_accuracy: 0.9452
# Epoch 14/40
# 163/163 [==============================] - 3s 18ms/step - loss: 0.1816 - accuracy: 0.9353 - val_loss: 0.1487 - val_accuracy: 0.9404
# Epoch 15/40
# 163/163 [==============================] - 3s 18ms/step - loss: 0.1861 - accuracy: 0.9317 - val_loss: 0.1443 - val_accuracy: 0.9465
# Epoch 16/40
# 163/163 [==============================] - 3s 18ms/step - loss: 0.1699 - accuracy: 0.9370 - val_loss: 0.1386 - val_accuracy: 0.9508
# Epoch 17/40
# 163/163 [==============================] - 3s 17ms/step - loss: 0.1692 - accuracy: 0.9375 - val_loss: 0.1623 - val_accuracy: 0.9368
# Epoch 18/40
# 163/163 [==============================] - 3s 17ms/step - loss: 0.1695 - accuracy: 0.9369 - val_loss: 0.1582 - val_accuracy: 0.9461
# Epoch 19/40
# 163/163 [==============================] - 3s 18ms/step - loss: 0.1583 - accuracy: 0.9441 - val_loss: 0.1315 - val_accuracy: 0.9530
# Epoch 20/40
# 163/163 [==============================] - 3s 17ms/step - loss: 0.1544 - accuracy: 0.9431 - val_loss: 0.1270 - val_accuracy: 0.9543
# Epoch 21/40
# 163/163 [==============================] - 3s 17ms/step - loss: 0.1477 - accuracy: 0.9442 - val_loss: 0.1276 - val_accuracy: 0.9528
# Epoch 22/40
# 163/163 [==============================] - 3s 17ms/step - loss: 0.1473 - accuracy: 0.9481 - val_loss: 0.1255 - val_accuracy: 0.9554
# Epoch 23/40
# 163/163 [==============================] - 3s 17ms/step - loss: 0.1434 - accuracy: 0.9483 - val_loss: 0.1280 - val_accuracy: 0.9532
# Epoch 24/40
# 163/163 [==============================] - 3s 17ms/step - loss: 0.1451 - accuracy: 0.9476 - val_loss: 0.1214 - val_accuracy: 0.9554
# Epoch 25/40
# 163/163 [==============================] - 3s 18ms/step - loss: 0.1422 - accuracy: 0.9486 - val_loss: 0.1226 - val_accuracy: 0.9548
# Epoch 26/40
# 163/163 [==============================] - 3s 17ms/step - loss: 0.1287 - accuracy: 0.9533 - val_loss: 0.1172 - val_accuracy: 0.9586
# Epoch 27/40
# 163/163 [==============================] - 3s 17ms/step - loss: 0.1415 - accuracy: 0.9482 - val_loss: 0.1230 - val_accuracy: 0.9554
# Epoch 28/40
# 163/163 [==============================] - 3s 17ms/step - loss: 0.1315 - accuracy: 0.9509 - val_loss: 0.1184 - val_accuracy: 0.9563
# Epoch 29/40
# 163/163 [==============================] - 3s 17ms/step - loss: 0.1301 - accuracy: 0.9525 - val_loss: 0.1240 - val_accuracy: 0.9537
# Epoch 30/40
# 163/163 [==============================] - 3s 17ms/step - loss: 0.1288 - accuracy: 0.9524 - val_loss: 0.1322 - val_accuracy: 0.9521
# Epoch 31/40
# 163/163 [==============================] - 3s 17ms/step - loss: 0.1266 - accuracy: 0.9520 - val_loss: 0.1197 - val_accuracy: 0.9571
# Epoch 32/40
# 163/163 [==============================] - 3s 17ms/step - loss: 0.1198 - accuracy: 0.9557 - val_loss: 0.1210 - val_accuracy: 0.9558
# Epoch 33/40
# 163/163 [==============================] - 3s 18ms/step - loss: 0.1228 - accuracy: 0.9553 - val_loss: 0.1283 - val_accuracy: 0.9524
# Epoch 34/40
# 163/163 [==============================] - 3s 17ms/step - loss: 0.1292 - accuracy: 0.9529 - val_loss: 0.1068 - val_accuracy: 0.9612
# Epoch 35/40
# 163/163 [==============================] - 3s 17ms/step - loss: 0.1217 - accuracy: 0.9559 - val_loss: 0.1135 - val_accuracy: 0.9584
# Epoch 36/40
# 163/163 [==============================] - 3s 18ms/step - loss: 0.1132 - accuracy: 0.9571 - val_loss: 0.1158 - val_accuracy: 0.9573
# Epoch 37/40
# 163/163 [==============================] - 3s 17ms/step - loss: 0.1163 - accuracy: 0.9586 - val_loss: 0.1077 - val_accuracy: 0.9603
# Epoch 38/40
# 163/163 [==============================] - 3s 21ms/step - loss: 0.1064 - accuracy: 0.9609 - val_loss: 0.1058 - val_accuracy: 0.9594
# Epoch 39/40
# 163/163 [==============================] - 3s 18ms/step - loss: 0.1073 - accuracy: 0.9600 - val_loss: 0.1114 - val_accuracy: 0.9578
# Epoch 40/40
# 163/163 [==============================] - 3s 21ms/step - loss: 0.1095 - accuracy: 0.9598 - val_loss: 0.1052 - val_accuracy: 0.9600
# 218/218 [==============================] - 1s 3ms/step
# voici le seuil médian 0.51634854
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.97      0.97      4140
#          1.0       0.96      0.94      0.95      2811
#
#     accuracy                           0.96      6951
#    macro avg       0.96      0.96      0.96      6951
# weighted avg       0.96      0.96      0.96      6951

# %%
evaluation_model(neuronal_network,X_train,X_test,Y_train,Y_test, batch_size=400, epochs=20,lr=0.00001)
#batch_size est le nombre d'individus utilisés pour la descente de gradient lors du Mini Bach
# 1 epoch est égale à N/batch_sige  fois ou on fait tourner l'algo
# Out:
# Epoch 1/20
# 41/41 [==============================] - 2s 37ms/step - loss: 0.0968 - accuracy: 0.9631 - val_loss: 0.1005 - val_accuracy: 0.9627
# Epoch 2/20
# 41/41 [==============================] - 1s 33ms/step - loss: 0.0895 - accuracy: 0.9668 - val_loss: 0.0989 - val_accuracy: 0.9622
# Epoch 3/20
# 41/41 [==============================] - 1s 34ms/step - loss: 0.0914 - accuracy: 0.9674 - val_loss: 0.0987 - val_accuracy: 0.9629
# Epoch 4/20
# 41/41 [==============================] - 1s 33ms/step - loss: 0.0871 - accuracy: 0.9663 - val_loss: 0.0982 - val_accuracy: 0.9633
# Epoch 5/20
# 41/41 [==============================] - 1s 33ms/step - loss: 0.0890 - accuracy: 0.9699 - val_loss: 0.0977 - val_accuracy: 0.9626
# Epoch 6/20
# 41/41 [==============================] - 1s 34ms/step - loss: 0.0851 - accuracy: 0.9694 - val_loss: 0.0978 - val_accuracy: 0.9643
# Epoch 7/20
# 41/41 [==============================] - 1s 34ms/step - loss: 0.0864 - accuracy: 0.9691 - val_loss: 0.0972 - val_accuracy: 0.9640
# Epoch 8/20
# 41/41 [==============================] - 2s 38ms/step - loss: 0.0822 - accuracy: 0.9708 - val_loss: 0.0979 - val_accuracy: 0.9636
# Epoch 9/20
# 41/41 [==============================] - 2s 37ms/step - loss: 0.0817 - accuracy: 0.9709 - val_loss: 0.0971 - val_accuracy: 0.9643
# Epoch 10/20
# 41/41 [==============================] - 1s 35ms/step - loss: 0.0840 - accuracy: 0.9689 - val_loss: 0.0967 - val_accuracy: 0.9646
# Epoch 11/20
# 41/41 [==============================] - 1s 36ms/step - loss: 0.0833 - accuracy: 0.9692 - val_loss: 0.0970 - val_accuracy: 0.9632
# Epoch 12/20
# 41/41 [==============================] - 1s 33ms/step - loss: 0.0812 - accuracy: 0.9711 - val_loss: 0.0962 - val_accuracy: 0.9636
# Epoch 13/20
# 41/41 [==============================] - 1s 36ms/step - loss: 0.0814 - accuracy: 0.9702 - val_loss: 0.0956 - val_accuracy: 0.9636
# Epoch 14/20
# 41/41 [==============================] - 2s 40ms/step - loss: 0.0807 - accuracy: 0.9705 - val_loss: 0.0957 - val_accuracy: 0.9635
# Epoch 15/20
# 41/41 [==============================] - 2s 39ms/step - loss: 0.0805 - accuracy: 0.9698 - val_loss: 0.0974 - val_accuracy: 0.9633
# Epoch 16/20
# 41/41 [==============================] - 1s 36ms/step - loss: 0.0802 - accuracy: 0.9706 - val_loss: 0.0967 - val_accuracy: 0.9632
# Epoch 17/20
# 41/41 [==============================] - 1s 36ms/step - loss: 0.0778 - accuracy: 0.9714 - val_loss: 0.0965 - val_accuracy: 0.9639
# Epoch 18/20
# 41/41 [==============================] - 2s 37ms/step - loss: 0.0795 - accuracy: 0.9705 - val_loss: 0.0955 - val_accuracy: 0.9637
# Epoch 19/20
# 41/41 [==============================] - 2s 38ms/step - loss: 0.0795 - accuracy: 0.9714 - val_loss: 0.0957 - val_accuracy: 0.9640
# Epoch 20/20
# 41/41 [==============================] - 1s 36ms/step - loss: 0.0762 - accuracy: 0.9711 - val_loss: 0.0958 - val_accuracy: 0.9646
# 218/218 [==============================] - 1s 3ms/step
# voici le seuil médian 0.6078162
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.98      0.97      4140
#          1.0       0.97      0.94      0.95      2811
#
#     accuracy                           0.96      6951
#    macro avg       0.96      0.96      0.96      6951
# weighted avg       0.96      0.96      0.96      6951

# %%
plt.hist(neuronal_network.predict(X_test),100,color='g',density=False,label='proba de test')
plt.grid()
plt.legend()
plt.title("Histogram sur les données test")
plt.show()


plt.hist(neuronal_network.predict(df_test_log_std),100,density=False,label='proba de validation')
plt.grid()
plt.legend()
plt.show()
# Out:
# 218/218 [==============================] - 1s 3ms/step
# 30/30 [==============================] - 0s 4ms/step

# %%
df_soumission6 = df_test_log_std.drop(df_test.columns,axis = 1)
df_soumission6['pos_label'] = neuronal_network.predict(df_test_log_std)
df_soumission6.to_csv("/home/ibotcazou/Bureau/Master_data_science/DATAS_M2/Apprentissage_Statistique_Panloup/Data_challenge/soumission6_neuronal1.csv")
# Out:
# 24/30 [=======================>......] - ETA: 0s
# 30/30 [==============================] - 0s 4ms/step

# %%
import pickle

# Entraînez votre modèle comme vous l'avez fait

# Sauvegardez le modèle dans un fichier
with open('/home/ibotcazou/Bureau/Master_data_science/DATAS_M2/Apprentissage_Statistique_Panloup/Data_challenge/modele_neuronal_MLP.pkl', 'wb') as fichier:
    pickle.dump(neuronal_network, fichier)

# %%
# Chargez le modèle à partir du fichier
with open('/home/ibotcazou/Bureau/Master_data_science/DATAS_M2/Apprentissage_Statistique_Panloup/Data_challenge/modele_neuronal_MLP.pkl', 'rb') as fichier:
    modele_charge = pickle.load(fichier)
